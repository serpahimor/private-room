# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif'] = ['SimHei']
plt.rcParams['axes.unicode_minus'] = False 
import pandas as pd

# %%
df=pd.read_excel('订单.xls')

# %%
df['下单时间']=pd.to_datetime(df['下单时间'])

# %%
df[df['门店名称'].str.contains('展示设计')].set_index('下单时间')['2018-8'].to_excel('temp.xls')

# %%
df[df['门店名称'].str.contains('展示设计')].set_index('下单时间')['2018-8':'2018-6']
# Out:
#                                      订单号                交费日前 空间名称      门店编号  \
# 下单时间
# 2018-07-31 11:58:38  1330100051807310001  8/23/2018 00:00:00  主人房  33010005
# 2018-07-30 10:33:08  1330100051807300002  7/31/2018 00:00:00  主人房  33010005
# 2018-07-30 10:32:27  1330100051807300001  7/31/2018 00:00:00  主人房  33010005
# 2018-07-28 15:07:23  1330100051807280061  7/31/2018 00:00:00  主人房  33010005
# 2018-07-28 15:06:18  1330100051807280011  7/31/2018 00:00:00  主人房  33010005
# 2018-07-28 15:04:42  1330100051807280010  7/31/2018 00:00:00  主人房  33010005
# 2018-07-28 15:01:01  1330100051807280060  7/31/2018 00:00:00  主人房  33010005
# 2018-07-28 14:59:42  1330100051807280009  7/31/2018 00:00:00  主人房  33010005
# 2018-07-28 14:59:08  1330100051807280008  7/31/2018 00:00:00  主人房  33010005
# 2018-07-28 14:58:36  1330100051807280007  7/31/2018 00:00:00  主人房  33010005
# 2018-07-28 14:57:57  1330100051807280006  7/31/2018 00:00:00  主人房  33010005
# ...

# %%
df.eval('''
    折后价利润=折后价-出厂价
    折后价利润率=折后价利润/出厂价
    结算价利润=结算价-出厂价
    结算价利润率=结算价利润/出厂价
    ''' ).to_excel('利润.xls')

# %%
df.eval('''
    折后价利润=折后价-出厂价
    折后价利润率=折后价利润/出厂价
    结算价利润=结算价-出厂价
    结算价利润率=结算价利润/出厂价
    ''' )[['折后价利润率','结算价利润率']].boxplot(figsize=(10,10))

# %%
df=df.eval('''
    折后价利润=折后价-出厂价
    折后价利润率=折后价利润/出厂价
    结算价利润=结算价-出厂价
    结算价利润率=结算价利润/出厂价
    ''' )

# %%
df.query('折后价利润率>0.9')
# Out:
#                        订单号                交费日前 空间名称      门店编号  \
# 19177  1330100041801060001  1/18/2018 00:00:00  主人房  33010004
#
#                   门店名称          员工编号 员工姓名       流水号 产品信息                下单时间  \
# 19177  浙江省杭州市萧山区布兰莎工程部  330100040001  沈玺臣  10002718    1 2018-01-06 12:33:41
#
#          ...         出厂价      零售价         折扣备注     折后价      精确价      结算价  \
# 19177    ...     2355.18  9358.35  工程单，我方包安装送货  4797.0  9358.35  3119.45
#
#          折后价利润    折后价利润率   结算价利润    结算价利润率
# 19177  2441.82  1.036787  764.27  0.324506
#
# [1 rows x 21 columns]
